# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

# %%
column_names = ['id','cycle']
features = ['o'+str(n) for n in range(1,4)]
features.extend(['s'+str(n) for n in range(1,22)])
column_names.extend(features)

# %%
train_df = pd.read_csv('data/train_FD001.txt',header=None,sep='\s+',names=column_names)
train_df.head()
# Out:
#    id  cycle      o1      o2     o3      s1      s2       s3       s4     s5  \
# 0   1      1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60  14.62
# 1   1      2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14  14.62
# 2   1      3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20  14.62
# 3   1      4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87  14.62
# 4   1      5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22  14.62
#
#    ...     s12      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06
# 1  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00
# 2  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95
# 3  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88
# 4  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90
#
#        s21
# 0  23.4190
# 1  23.4236
# 2  23.3442
# 3  23.3739
# ...

# %%
train_df['id'].value_counts().plot.bar(figsize=(17,7));

# %%
train_df[train_df['id'] == 1]['o2'].plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df.set_index('cycle',inplace=True)

# %%
for id in train_df['id'].unique():
    train_df[train_df['id'] == id]['s12'].plot()

# %%
plt.figure(figsize=(17,15))
ax = sns.heatmap(train_df[train_df['id'] == 1][features].corr().round(2),cmap='RdBu',annot=True,linewidth=0.5)
